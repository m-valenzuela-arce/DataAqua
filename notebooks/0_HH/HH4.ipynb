# %%
import pandas as pd
from datetime import datetime, timedelta

# %%
# Cargar el dataset principal con los datos meteorológicos de las estaciones
df_meteorologico = pd.read_excel('./Datos/REMAS_Etchojoa_Cajeme_2022-2023.xlsx')

# %%
# Cargar el dataset con los valores de ETo
df_eto = pd.read_excel('./Datos/ETo_REMAS_Etchojoa_Cajeme_2022-2023.xlsx')

# %%
# Filtrar por el municipio y la estación deseada
municipio_seleccionado = "Etchojoa"  # Cambia el municipio aquí
estacion_seleccionada = "BLOCK 2732 (BUAYSIACOBE)"  # Cambia el nombre de la estación específica aquí

df_meteorologico = df_meteorologico[
    (df_meteorologico['Municipio'] == municipio_seleccionado) & 
    (df_meteorologico['Estación'] == estacion_seleccionada)
]

# %%
# Renombrar las columnas en df_eto para facilitar la unión
df_eto.rename(columns={'REFERENCIA': 'Estación', 'FECHA': 'Fecha'}, inplace=True)

# %%
# Asegurarnos de que ambas columnas de fecha están en el mismo formato
df_meteorologico['Fecha'] = pd.to_datetime(df_meteorologico['Fecha'], format='%m/%d/%Y')
df_eto['Fecha'] = pd.to_datetime(df_eto['Fecha'], format='%m/%d/%Y')

# %%
# Filtrar el DataFrame de ETo por la misma estación
df_eto = df_eto[df_eto['Estación'] == estacion_seleccionada]

# %%
# Unir ambos DataFrames en función de la estación (Estación) y la fecha (Fecha)
df = pd.merge(df_meteorologico, df_eto[['Estación', 'Fecha', 'ETO']], on=['Estación', 'Fecha'], how='inner')

# # Guardar el DataFrame unido en un archivo Excel para inspección
# df.to_excel('df_utilizado_final.xlsx', index=False)

# %%
# Definir los parámetros del cultivo (trigo)
pcc = 140  # Periodo de crecimiento del cultivo en días
kc_values = {
    'inicio': 0.15,  # Kc inicial
    'medio': 1.15,   # Kc medio
    'final': 0.50    # Kc final
}
rendimiento = 7.37  # Rendimiento del cultivo en ton/ha

# %%
# Definir la fecha de inicio en el código
fecha_inicio_str = "11/30/2022"  # Cambia la fecha de inicio según el periodo deseado
fecha_inicio = datetime.strptime(fecha_inicio_str, '%m/%d/%Y')

# Verificar si hay suficientes días para el periodo de cultivo
fecha_fin = fecha_inicio + timedelta(days=pcc - 1)
ultima_fecha = df['Fecha'].max()

# %%
fecha_inicio
# Out:
# datetime.datetime(2022, 11, 30, 0, 0)

# %%
ultima_fecha
# Out:
# Timestamp('2023-12-31 00:00:00')

# %%
if fecha_fin > ultima_fecha:
    print(f"No hay suficientes datos para un periodo de {pcc} días desde la fecha de inicio {fecha_inicio_str}.")
else:
    # Filtrar el DataFrame para el periodo de 140 días desde la fecha de inicio y hacer una copia para evitar warnings
    df_periodo = df[(df['Fecha'] >= fecha_inicio) & (df['Fecha'] <= fecha_fin)].copy()

# %%
pd.set_option('display.max_rows', None)

# %%
df_periodo
# Out:
#                      Estación Municipio    Zona agrícola        Lat  \
# 333  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 334  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 335  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 336  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 337  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 338  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 339  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 340  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 341  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 342  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 343  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 344  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 345  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 346  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 347  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 348  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 349  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 350  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 351  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 352  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 353  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 354  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 355  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 356  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 357  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 358  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 359  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 360  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 361  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 362  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 363  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 364  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 365  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 366  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 367  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 368  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 369  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 370  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 371  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 372  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 373  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 374  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 375  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 376  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 377  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 378  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 379  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 380  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 381  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 382  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 383  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 384  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 385  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 386  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 387  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 388  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 389  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 390  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 391  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 392  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 393  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 394  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 395  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 396  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 397  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 398  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 399  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 400  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 401  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 402  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 403  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 404  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 405  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 406  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 407  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 408  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 409  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 410  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 411  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 412  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 413  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 414  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 415  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 416  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 417  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 418  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 419  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 420  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 421  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 422  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 423  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 424  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 425  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 426  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 427  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 428  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 429  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 430  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 431  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 432  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 433  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 434  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 435  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 436  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 437  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 438  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 439  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 440  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 441  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 442  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 443  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 444  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 445  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 446  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 447  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 448  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 449  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 450  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 451  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 452  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 453  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 454  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 455  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 456  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 457  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 458  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 459  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 460  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 461  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 462  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 463  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 464  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 465  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 466  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 467  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 468  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 469  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 470  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 471  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
# 472  BLOCK 2732 (BUAYSIACOBE)  Etchojoa  Valle del Yaqui  27.032779
#
#             Lon      Fecha Temperatura promedio (°C) Temperatura máxima (°C)  \
# 333 -109.689117 2022-11-30                     16.68                   26.91
# 334 -109.689117 2022-12-01                     17.89                   30.65
# 335 -109.689117 2022-12-02                     20.78                    32.6
# 336 -109.689117 2022-12-03                     20.56                   29.34
# 337 -109.689117 2022-12-04                     20.41                   30.26
# 338 -109.689117 2022-12-05                      20.8                   28.48
# 339 -109.689117 2022-12-06                     19.52                   23.23
# 340 -109.689117 2022-12-07                     19.02                   22.64
# 341 -109.689117 2022-12-08                     18.33                   27.32
# 342 -109.689117 2022-12-09                     16.11                    25.1
# 343 -109.689117 2022-12-10                     15.72                   24.95
# 344 -109.689117 2022-12-11                     13.83                   26.18
# 345 -109.689117 2022-12-12                     14.46                   25.77
# 346 -109.689117 2022-12-13                     13.91                   21.85
# 347 -109.689117 2022-12-14                     12.81                   22.64
# 348 -109.689117 2022-12-15                     12.34                   23.74
# 349 -109.689117 2022-12-16                      12.9                   20.57
# 350 -109.689117 2022-12-17                     13.41                   23.39
# 351 -109.689117 2022-12-18                     12.95                   22.26
# 352 -109.689117 2022-12-19                     13.76                   25.19
# 353 -109.689117 2022-12-20                     14.58                   26.36
# 354 -109.689117 2022-12-21                     13.32                   24.14
# 355 -109.689117 2022-12-22                     13.95                   25.63
# 356 -109.689117 2022-12-23                     14.05                   25.77
# 357 -109.689117 2022-12-24                     13.53                   25.06
# 358 -109.689117 2022-12-25                     15.24                    29.2
# 359 -109.689117 2022-12-26                     14.31                   26.98
# 360 -109.689117 2022-12-27                     14.73                    28.9
# 361 -109.689117 2022-12-28                     15.29                   24.49
# 362 -109.689117 2022-12-29                     17.59                   21.19
# 363 -109.689117 2022-12-30                      17.1                   24.53
# 364 -109.689117 2022-12-31                     16.38                   27.27
# 365 -109.689117 2023-01-01                     16.19                   24.34
# 366 -109.689117 2023-01-02                     15.88                   21.95
# 367 -109.689117 2023-01-03                     12.91                   22.87
# 368 -109.689117 2023-01-04                     15.07                   26.46
# 369 -109.689117 2023-01-05                     16.26                   27.97
# 370 -109.689117 2023-01-06                     15.36                   25.39
# 371 -109.689117 2023-01-07                     14.42                   24.49
# 372 -109.689117 2023-01-08                     14.63                   23.49
# 373 -109.689117 2023-01-09                     13.64                   24.21
# 374 -109.689117 2023-01-10                     15.33                   27.14
# 375 -109.689117 2023-01-11                     14.89                   26.03
# 376 -109.689117 2023-01-12                     14.85                   25.17
# 377 -109.689117 2023-01-13                     14.77                   25.73
# 378 -109.689117 2023-01-14                     14.76                   26.75
# 379 -109.689117 2023-01-15                     14.76                   23.87
# 380 -109.689117 2023-01-16                      14.9                   23.94
# 381 -109.689117 2023-01-17                     13.71                   20.51
# 382 -109.689117 2023-01-18                     12.93                   21.57
# 383 -109.689117 2023-01-19                     12.08                   21.83
# 384 -109.689117 2023-01-20                     11.77                   22.31
# 385 -109.689117 2023-01-21                     12.17                   21.46
# 386 -109.689117 2023-01-22                     10.06                   21.39
# 387 -109.689117 2023-01-23                      11.5                   21.54
# 388 -109.689117 2023-01-24                     10.87                   19.33
# 389 -109.689117 2023-01-25                     11.41                    22.5
# 390 -109.689117 2023-01-26                      13.8                   20.75
# 391 -109.689117 2023-01-27                      11.8                   18.28
# 392 -109.689117 2023-01-28                     13.03                   21.58
# 393 -109.689117 2023-01-29                     12.98                   24.09
# 394 -109.689117 2023-01-30                     12.45                   21.38
# 395 -109.689117 2023-01-31                     13.39                   21.53
# 396 -109.689117 2023-02-01                     11.76                   18.26
# 397 -109.689117 2023-02-02                     12.59                   22.45
# 398 -109.689117 2023-02-03                     14.46                   24.63
# 399 -109.689117 2023-02-04                     14.83                   24.11
# 400 -109.689117 2023-02-05                     14.46                   24.12
# 401 -109.689117 2023-02-06                     14.08                    21.9
# 402 -109.689117 2023-02-07                     14.26                   23.08
# 403 -109.689117 2023-02-08                      13.2                   25.58
# 404 -109.689117 2023-02-09                     11.63                   22.63
# 405 -109.689117 2023-02-10                     12.52                    24.8
# 406 -109.689117 2023-02-11                     12.25                   21.01
# 407 -109.689117 2023-02-12                     14.81                   23.64
# 408 -109.689117 2023-02-13                     13.45                   18.92
# 409 -109.689117 2023-02-14                     12.12                    20.9
# 410 -109.689117 2023-02-15                     12.09                   20.37
# 411 -109.689117 2023-02-16                     11.46                   19.81
# 412 -109.689117 2023-02-17                      11.9                   19.34
# 413 -109.689117 2023-02-18                     15.74                   20.56
# 414 -109.689117 2023-02-19                     16.06                   23.88
# 415 -109.689117 2023-02-20                     15.37                   23.26
# 416 -109.689117 2023-02-21                     15.35                   21.05
# 417 -109.689117 2023-02-22                     13.74                   21.84
# 418 -109.689117 2023-02-23                     13.49                   21.98
# 419 -109.689117 2023-02-24                     12.56                   19.66
# 420 -109.689117 2023-02-25                     14.94                   21.43
# 421 -109.689117 2023-02-26                     15.24                   22.45
# 422 -109.689117 2023-02-27                     13.07                   22.78
# 423 -109.689117 2023-02-28                     12.94                   21.33
# 424 -109.689117 2023-03-01                     12.88                   17.33
# 425 -109.689117 2023-03-02                     12.55                   19.53
# 426 -109.689117 2023-03-03                      12.2                   21.87
# 427 -109.689117 2023-03-04                     12.34                   23.79
# 428 -109.689117 2023-03-05                     12.96                   24.74
# 429 -109.689117 2023-03-06                     14.44                   25.56
# 430 -109.689117 2023-03-07                     14.75                    24.4
# 431 -109.689117 2023-03-08                     15.74                   25.59
# 432 -109.689117 2023-03-09                     16.58                   25.94
# 433 -109.689117 2023-03-10                     16.58                   25.21
# 434 -109.689117 2023-03-11                     17.72                   26.52
# 435 -109.689117 2023-03-12                     19.41                   29.18
# 436 -109.689117 2023-03-13                      18.8                   27.68
# 437 -109.689117 2023-03-14                     17.32                   27.38
# 438 -109.689117 2023-03-15                     17.23                   27.53
# 439 -109.689117 2023-03-16                     18.25                   26.48
# 440 -109.689117 2023-03-17                     18.14                   23.19
# 441 -109.689117 2023-03-18                     17.68                   24.15
# 442 -109.689117 2023-03-19                     17.57                   24.53
# 443 -109.689117 2023-03-20                     18.41                   26.89
# 444 -109.689117 2023-03-21                     18.87                   26.49
# 445 -109.689117 2023-03-22                     18.07                   27.27
# 446 -109.689117 2023-03-23                     16.39                   23.29
# 447 -109.689117 2023-03-24                      14.5                    22.4
# 448 -109.689117 2023-03-25                     13.84                   23.23
# 449 -109.689117 2023-03-26                     14.67                      24
# 450 -109.689117 2023-03-27                     14.51                   23.74
# 451 -109.689117 2023-03-28                     15.08                   23.73
# 452 -109.689117 2023-03-29                     15.49                   26.13
# 453 -109.689117 2023-03-30                     18.18                   26.87
# 454 -109.689117 2023-03-31                     15.81                   25.43
# 455 -109.689117 2023-04-01                     16.53                   26.04
# 456 -109.689117 2023-04-02                     16.61                   28.14
# 457 -109.689117 2023-04-03                      16.6                   26.75
# 458 -109.689117 2023-04-04                     15.86                   25.04
# 459 -109.689117 2023-04-05                     13.43                   23.38
# 460 -109.689117 2023-04-06                     13.77                   24.38
# 461 -109.689117 2023-04-07                     14.94                   25.19
# 462 -109.689117 2023-04-08                     16.93                   28.66
# 463 -109.689117 2023-04-09                     18.03                   30.37
# 464 -109.689117 2023-04-10                     17.29                   29.89
# 465 -109.689117 2023-04-11                     18.59                   29.64
# 466 -109.689117 2023-04-12                     19.47                   31.44
# 467 -109.689117 2023-04-13                      17.9                   27.01
# 468 -109.689117 2023-04-14                     18.76                    27.9
# 469 -109.689117 2023-04-15                     18.39                   27.63
# 470 -109.689117 2023-04-16                     19.66                   30.19
# 471 -109.689117 2023-04-17                     19.58                   31.03
# 472 -109.689117 2023-04-18                     19.59                   29.34
#
#     Temperatura mínima (°C) Humedad relativa (%) Precipitación (mm)   ETO
# 333                     9.2                70.04                  0  4.28
# 334                    8.31                68.31                0.1  5.02
# 335                   12.15                60.48                  0  6.27
# 336                   14.61                 68.8                  0  4.75
# 337                   12.92                74.61                  0  4.10
# 338                   15.51                77.27                0.2  3.01
# 339                   17.58                87.47                  4  1.20
# 340                    15.5                86.01                0.2  1.68
# 341                   12.92                75.48                  0  4.16
# 342                    9.64                69.61                  0  4.20
# 343                    8.99                69.02                  0  4.21
# 344                    5.35                72.66                  0  3.72
# 345                    6.02                70.07                  0  4.30
# 346                    7.09                70.03                  0  3.82
# 347                     3.9                61.33                  0  5.12
# 348                    2.46                 60.2                  0  4.77
# 349                     4.9                61.48                  0  3.56
# 350                    5.23                66.72                  0  3.88
# 351                    5.63                71.34                  0  3.70
# 352                    3.71                61.13                  0  5.15
# 353                    5.29                58.82                  0  4.92
# 354                    3.78                72.52                  0  3.66
# 355                    4.68                72.37                0.1  3.96
# 356                    3.99                 68.1                  0  4.20
# 357                    3.71                69.86                  0  4.03
# 358                    4.71                62.44                  0  5.31
# 359                     4.8                63.97                  0  4.40
# 360                    4.88                68.94                  0  4.33
# 361                    6.26                66.89                  0  3.82
# 362                   14.82                79.52                2.6  1.69
# 363                   12.23                79.36                  0  3.11
# 364                   10.17                77.23                  0  3.51
# 365                    8.79                 81.7                  0  2.90
# 366                    9.26                80.86                0.2  2.43
# 367                     4.7                73.89                  0  3.38
# 368                    4.49                66.25                  0  4.43
# 369                    5.98                63.07                  0  5.08
# 370                    6.04                71.52                  0  3.86
# 371                    7.54                82.42                0.2  3.04
# 372                    7.02                80.01                  0  3.02
# 373                    3.74                80.32                0.1  3.34
# 374                    5.05                70.78                0.1  4.31
# 375                    5.61                68.93                  0  4.18
# 376                    6.61                72.35                  0  3.74
# 377                    5.61                76.38                  0  3.51
# 378                    6.78                82.24                0.1  3.21
# 379                    7.93                   85                0.3  2.42
# 380                     7.3                84.95                0.1  2.81
# 381                    7.86                87.14                0.1  1.34
# 382                    4.61                71.84                0.2  4.20
# 383                    3.74                74.16                  0  3.39
# 384                    2.42                 74.5                0.1  3.68
# 385                    4.82                65.43                  0  4.47
# 386                    1.38                73.36                  0  3.20
# 387                    1.18                74.96                0.2  3.75
# 388                    1.36                55.81                  0  5.01
# 389                    0.11                60.31                  0  4.96
# 390                    6.88                60.18                  0  4.78
# 391                    3.15                72.67                  0  2.54
# 392                    7.12                 75.6                  0  2.32
# 393                    4.18                75.25                  0  3.73
# 394                    4.39                81.84                0.1  2.98
# 395                       8                79.54                0.1  2.55
# 396                    4.75                81.99                  0  2.40
# 397                     3.8                78.69                  0  3.35
# 398                     5.7                79.49                0.1  3.33
# 399                    6.33                81.77                  0  3.18
# 400                    6.16                82.86                0.1  3.15
# 401                    7.55                82.51                0.2  3.00
# 402                    6.91                58.47                  0  5.61
# 403                    1.94                62.48                  0  5.51
# 404                     1.8                74.29                  0  3.25
# 405                    4.84                78.33                  0  3.05
# 406                    5.08                83.93                  0  1.55
# 407                    8.23                76.49                  0  3.27
# 408                    6.98                76.72                  0  2.14
# 409                    4.95                73.39                  0  3.32
# 410                    5.18                 77.4                  0  3.21
# 411                    5.84                72.81                  0  3.34
# 412                    2.94                79.18                  0  2.56
# 413                      11                79.62                0.3  2.37
# 414                   10.67                 77.6                  0  3.15
# 415                   10.08                81.43                  0  3.09
# 416                   10.26                85.03                0.1  2.14
# 417                    7.19                79.36                0.1  3.37
# 418                    6.43                80.25                  0  3.44
# 419                    5.81                85.33                  0  1.96
# 420                    9.37                78.23                  0  2.39
# 421                    8.41                 79.2                  0  3.44
# 422                    6.16                76.34                  0  3.55
# 423                    4.26                78.98                  0  2.96
# 424                    6.98                87.04                  0  0.73
# 425                    5.82                 74.9                0.2  4.04
# 426                    3.47                71.96                  0  3.92
# 427                    3.69                85.63                0.2  3.16
# 428                    3.18                77.74                0.2  4.14
# 429                     4.5                75.33                  0  4.25
# 430                    5.75                79.02                  0  3.34
# 431                     8.4                78.87                  0  3.78
# 432                    9.72                79.18                  0  4.06
# 433                    8.09                77.41                  0  4.18
# 434                    7.67                71.23                  0  4.86
# 435                    11.4                72.57                  0  5.15
# 436                   10.26                68.73                  0  5.66
# 437                    8.09                 71.8                  0  4.96
# 438                    7.46                73.65                  0  4.61
# 439                   10.81                77.73                  0  4.07
# 440                   15.12                85.74                0.8  1.60
# 441                   12.68                82.57                  0  3.53
# 442                   11.31                77.58                  0  4.14
# 443                   11.02                73.25                  0  4.98
# 444                   13.12                77.85                  0  4.30
# 445                    9.77                80.11                  0  4.15
# 446                   10.48                76.61                  0  4.08
# 447                    6.95                72.68                  0  4.60
# 448                    5.61                76.08                  0  4.27
# 449                    5.44                72.87                0.1  4.72
# 450                    5.42                76.85                  0  3.57
# 451                    8.55                80.02                  0  3.22
# 452                    4.81                80.33                0.1  4.01
# 453                   11.16                72.02                  0  4.54
# 454                    6.02                73.33                  0  4.70
# 455                    6.35                75.53                  0  4.55
# 456                    7.81                72.23                  0  4.99
# 457                    6.57                71.98                  0  4.78
# 458                    7.81                70.43                  0  4.83
# 459                    5.44                68.59                  0  4.38
# 460                    3.14                 75.5                  0  4.61
# 461                    4.68                75.05                0.1  4.93
# 462                    5.63                67.97                  0  5.89
# 463                    6.53                60.98                  0  6.68
# 464                    5.54                66.56                  0  5.71
# 465                    7.71                68.31                  0  5.83
# 466                    9.23                63.12                  0  7.15
# 467                   10.94                71.71                  0  4.19
# 468                   11.19                75.31                  0  5.34
# 469                    8.99                72.39                0.1  5.60
# 470                   10.63                71.39                  0  5.96
# 471                    9.98                67.51                  0  6.80
# 472                   10.78                67.11                  0  5.77

# %%
    # Crear y asignar la columna 'Kc' como float para evitar problemas de tipo de datos
    df_periodo['Kc'] = 0.0
    df_periodo.loc[df_periodo.index < 45, 'Kc'] = kc_values['inicio']
    df_periodo.loc[(df_periodo.index >= 45) & (df_periodo.index < 95), 'Kc'] = kc_values['medio']
    df_periodo.loc[df_periodo.index >= 95, 'Kc'] = kc_values['final']

    # Calcular ETc (Evapotranspiración de cultivo)
    df_periodo['ETc'] = df_periodo['Kc'] * df_periodo['ETO']

    # Definir la función para calcular Precipitación efectiva
    def calcular_precip_efectiva(precipitacion_total):
        if precipitacion_total < 250:
            # Cálculo de la precipitación efectiva cuando es menor a 250 mm
            precip_efectiva = precipitacion_total * (125 - 0.2 * precipitacion_total) / 125
        else:
            # Cálculo de la precipitación efectiva cuando es mayor o igual a 250 mm
            precip_efectiva = 125 + 0.1 * precipitacion_total
        return precip_efectiva

    # Calcular Precipitación efectiva para cada registro
    df_periodo['Precipitación efectiva'] = df_periodo['Precipitación (mm)'].apply(calcular_precip_efectiva)

    # Calcular ETverde (Evapotranspiración de agua verde)
    df_periodo['ETverde'] = df_periodo[['ETc', 'Precipitación efectiva']].min(axis=1)

    # Calcular ETazul (Evapotranspiración de agua azul)
    df_periodo['ETazul'] = (df_periodo['ETc'] - df_periodo['Precipitación efectiva']).apply(lambda x: max(0, x))

    # Calcular el uso de agua verde y agua azul total en el periodo de 140 días
    uso_agua_verde = 10 * df_periodo['ETverde'].sum()  # m³/ha
    uso_agua_azul = 10 * df_periodo['ETazul'].sum()    # m³/ha

    # Calcular la Huella Hídrica en m³/ton para agua verde y agua azul
    hh_proc_verde = uso_agua_verde / rendimiento
    hh_proc_azul = uso_agua_azul / rendimiento

    # Mostrar los resultados
    print(f"Uso de Agua Verde en Cultivo para los {pcc} días desde {fecha_inicio_str}: {uso_agua_verde} m³/ha")
    print(f"Uso de Agua Azul en Cultivo para los {pcc} días desde {fecha_inicio_str}: {uso_agua_azul} m³/ha")
    print(f"Huella Hídrica de Agua Verde (HHproc, verde): {hh_proc_verde} m³/ton")
    print(f"Huella Hídrica de Agua Azul (HHproc, azul): {hh_proc_azul} m³/ton")
# Out:
# Uso de Agua Verde en Cultivo para los 140 días desde 11/30/2022: 66.42760000000001 m³/ha
# Uso de Agua Azul en Cultivo para los 140 días desde 11/30/2022: 2667.5224 m³/ha
# Huella Hídrica de Agua Verde (HHproc, verde): 9.01324287652646 m³/ton
# Huella Hídrica de Agua Azul (HHproc, azul): 361.9433378561736 m³/ton
